# %% [markdown]
# <a href="https://colab.research.google.com/github/CisnerosJM/miRNA_Plants/blob/main/Proyecto_Maiz_Arroz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !gdown --id 1AYvZvF_CWsX6HE_n8SPEuMgOGfQCLSBm

# !gunzip RNAhybrid-2.1.2.tar.gz
# !tar xvf RNAhybrid-2.1.2.tar
# %cd RNAhybrid-2.1.2/
# !./configure
# !make
# !make install
# Out:
# /usr/local/lib/python3.7/dist-packages/gdown/cli.py:131: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   category=FutureWarning,
# Downloading...
# From: https://drive.google.com/uc?id=1AYvZvF_CWsX6HE_n8SPEuMgOGfQCLSBm
# To: /content/RNAhybrid-2.1.2.tar.gz
# 100% 182k/182k [00:00<00:00, 63.4MB/s]
# RNAhybrid-2.1.2/
# RNAhybrid-2.1.2/aclocal.m4
# RNAhybrid-2.1.2/AUTHORS
# RNAhybrid-2.1.2/ChangeLog
# RNAhybrid-2.1.2/config.guess
# RNAhybrid-2.1.2/config.h.in
# RNAhybrid-2.1.2/configure
# RNAhybrid-2.1.2/configure.in
# RNAhybrid-2.1.2/COPYING
# RNAhybrid-2.1.2/depcomp
# RNAhybrid-2.1.2/examples/
# RNAhybrid-2.1.2/examples/3UTR_fly.freq
# RNAhybrid-2.1.2/examples/3UTR_human.freq
# RNAhybrid-2.1.2/examples/3UTR_worm.freq
# RNAhybrid-2.1.2/examples/cbr-hbl-1.fasta
# RNAhybrid-2.1.2/examples/cel-hbl-1.fasta
# RNAhybrid-2.1.2/examples/cel-let-7.fasta
# RNAhybrid-2.1.2/examples/coding_fly.freq
# ...

# %%
# %cd /content/
# !gdown --id 19EK66_sa9npnTKJU-jQGkwxZ2FEzAjjj # miRNA arroz

# !gdown --id 1SBC1SIC3Dz0-VfZnJvDtfqTI5_AhDxeZ # database ribosoma arroz

# !gdown --id 11Tr7bSG77KHL8lsrpiNNYNe7qSM-d3Nt # miRNA maiz

# !gdown --id 1kY4meSnYb9uDn1P0IIkJjTamHZiH5tXF # database ribosome maiz
# Out:
# /content
# /usr/local/lib/python3.7/dist-packages/gdown/cli.py:131: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   category=FutureWarning,
# Downloading...
# From: https://drive.google.com/uc?id=19EK66_sa9npnTKJU-jQGkwxZ2FEzAjjj
# To: /content/oryza_sativa_mirna.txt
# 100% 113k/113k [00:00<00:00, 81.1MB/s]
# /usr/local/lib/python3.7/dist-packages/gdown/cli.py:131: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   category=FutureWarning,
# Downloading...
# From: https://drive.google.com/uc?id=1SBC1SIC3Dz0-VfZnJvDtfqTI5_AhDxeZ
# To: /content/oryza_sativa_ribosome.fasta
# 100% 152k/152k [00:00<00:00, 81.5MB/s]
# ...

# %%
# !pwd
# %cd /content/
# !pwd
# !RNAhybrid -s 3utr_worm -t zea_mays_ribosome.txt -q oryza_sativa_mirna.txt >ribomaiz-mirnaarroz.fasta
# Out:
# /content
# /content
# /content

# %%
from google.colab import files
files.download("ribomaiz-mirnaarroz.fasta")

# %% [markdown]
# * cruce de RNA con secuencias de ribosomas
# * ribosomas arroz vs maiz
# * cual es el sentido del miRNA
# * la secuencias de miRNA es complementaria a target- revisar
